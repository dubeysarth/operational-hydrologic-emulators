# %% [markdown]
# # Setting Up

# %%
import os
os.chdir('/data/sarth/operational-hydrologic-emulators')

# %%
import configparser
cfg = configparser.ConfigParser()
cfg.optionxform = str
cfg.read('defaults.ini')
cfg = {s: dict(cfg.items(s)) for s in cfg.sections()}
PATHS = cfg['PATHS']
PATHS
# Out:
# {'root': '/data/sarth/operational-hydrologic-emulators',
#  'datadir': '/data/sarth/operational-hydrologic-emulators/data',
#  'utils': '/data/sarth/operational-hydrologic-emulators/utils',
#  'notebooks': '/data/sarth/operational-hydrologic-emulators/notebooks',
#  'assets': '/data/sarth/operational-hydrologic-emulators/data/assets',
#  'datasets': '/data/sarth/operational-hydrologic-emulators/data/datasets',
#  'experiments': '/data/sarth/operational-hydrologic-emulators/data/experiments'}

# %% [markdown]
# # Get Predictions

# %% [markdown]
# # Get Metrics

# %% [markdown]
# # Variables

# %%
# CAMELS-US: 395 Catchments
# X_dynamic_ERA5: torch.Size([4389, 395, 20])
# X_dynamic_GPM: torch.Size([4389, 395, 3])
# X_dynamic_HRES: torch.Size([4389, 395, 10, 5])
# X_dynamic_ERA5Land: torch.Size([4389, 395, 25])
# X_static: torch.Size([395, 77])
# y_gauge: torch.Size([4389, 395, 1])
# y_sim: torch.Size([4389, 395, 3])
# encodings: torch.Size([4389, 395, 4])
# timestamps: 4389 (1998-01-02 - 2010-01-10)

# %% [markdown]
# # X_dynamic_ERA5

# %%
# 'total_precipitation', # SUM
# '2m_temperature', # MEAN
# 'surface_net_solar_radiation', # SUM
# 'surface_net_thermal_radiation', # SUM
# 'surface_pressure', # MEAN
# 'evaporation', # SUM
# 'potential_evaporation', # SUM
# '2m_dewpoint_temperature', # MEAN
# '10m_u_component_of_wind', # MEAN
# '10m_v_component_of_wind', # MEAN
# 'snowfall', # MEAN
# 'snow_depth', # MEAN
# 'snowmelt', # MEAN
# 'volumetric_soil_water_layer_1', # MEAN
# 'volumetric_soil_water_layer_2', # MEAN
# 'volumetric_soil_water_layer_3', # MEAN
# 'volumetric_soil_water_layer_4', # MEAN
# 'runoff', # SUM
# 'surface_runoff', # SUM
# 'sub_surface_runoff' # SUM

# %% [markdown]
# # y_sim

# %%
# 'dynamic_GloFAS_discharge_mm', # mm/day SUM
# 'dynamic_GloFAS_soil_wetness_index', # m3/m3 MEAN
# 'dynamic_GloFAS_runoff_water_equivalent', # kg/m2 SUM

# %% [markdown]
# # encodings

# %%
# 'encoding_solar_insolation',
# 'encoding_sine_month',
# 'encoding_sine_dayofyear',
# 'encoding_sine_weekofyear'

# %% [markdown]
# # X_dynamic_GPM

# %%
# 'Early_Run', 
# 'Late_Run', 
# 'Final_Run'

# %% [markdown]
# # X_dynamic_HRES

# %%
# 'total_precipitation_24hr',
# '2m_temperature',
# 'surface_pressure',
# '10m_u_component_of_wind',
# '10m_v_component_of_wind'

# %% [markdown]
# # X_static

# %%
# 'static_ERA5_high_vegetation_cover'
# 'static_ERA5_low_vegetation_cover'
# 'static_HWSD_S_CLAY', 
# 'static_HWSD_S_GRAVEL', 
# 'static_HWSD_S_SAND', 
# 'static_HWSD_S_SILT',
# 'static_HWSD_T_CLAY', 
# 'static_HWSD_T_GRAVEL', 
# 'static_HWSD_T_SAND', 
# 'static_HWSD_T_SILT',
# 'encoding_transformed_latitude', 
# 'encoding_transformed_longitude',
# 'static_uparea', 
# 'static_GloFAS_cellarea_km2',
# 'static_terrain_aspect_mean', 
# 'static_terrain_aspect_std',
# 'static_terrain_curvature_mean', 
# 'static_terrain_curvature_std',
# 'static_terrain_elv_mean', 
# 'static_terrain_elv_std',
# 'static_terrain_slope_degrees_mean', 
# 'static_terrain_slope_degrees_std',
# 'static_terrain_wth_mean', 
# 'static_terrain_wth_std',
# 'static_GloFAS_chanbnkf', 
# 'static_GloFAS_chanbw', 
# 'static_GloFAS_chanflpn', 
# 'static_GloFAS_changrad', 
# 'static_GloFAS_chanlength', 
# 'static_GloFAS_chanman', 
# 'static_GloFAS_chans',
# 'static_GloFAS_fracforest', 
# 'static_GloFAS_fracirrigated', 
# 'static_GloFAS_fracother', 
# 'static_GloFAS_fracrice', 
# 'static_GloFAS_fracsealed', 
# 'static_GloFAS_fracwater',
# 'static_ClimSumm_aridity_ERA5',
# 'static_ClimSumm_aridity_FAO_PM',
# 'static_ClimSumm_frac_snow',
# 'static_ClimSumm_high_prec_dur',
# 'static_ClimSumm_high_prec_freq',
# 'static_ClimSumm_low_prec_dur',
# 'static_ClimSumm_low_prec_freq',
# 'static_ClimSumm_moisture_index_ERA5',
# 'static_ClimSumm_moisture_index_FAO_PM',
# 'static_ClimSumm_p_mean',
# 'static_ClimSumm_pet_mean_ERA5',
# 'static_ClimSumm_pet_mean_FAO_PM',
# 'static_ClimSumm_seasonality_ERA5',
# 'static_ClimSumm_seasonality_FAO_PM'
# 'static_ERA5_soil_type',
# 'static_ERA5_soil_type',
# 'static_ERA5_soil_type',
# 'static_ERA5_soil_type',
# 'static_ERA5_soil_type',
# 'static_ERA5_soil_type',
# 'static_ERA5_soil_type',
# 'static_ERA5_soil_type',
# 'static_ERA5_type_of_high_vegetation',
# 'static_ERA5_type_of_high_vegetation',
# 'static_ERA5_type_of_high_vegetation',
# 'static_ERA5_type_of_high_vegetation',
# 'static_ERA5_type_of_high_vegetation',
# 'static_ERA5_type_of_high_vegetation',
# 'static_ERA5_type_of_high_vegetation',
# 'static_ERA5_type_of_low_vegetation',
# 'static_ERA5_type_of_low_vegetation',
# 'static_ERA5_type_of_low_vegetation',
# 'static_ERA5_type_of_low_vegetation',
# 'static_ERA5_type_of_low_vegetation',
# 'static_ERA5_type_of_low_vegetation',
# 'static_ERA5_type_of_low_vegetation',
# 'static_ERA5_type_of_low_vegetation',
# 'static_ERA5_type_of_low_vegetation',
# 'static_ERA5_type_of_low_vegetation',
# 'static_ERA5_type_of_low_vegetation',
